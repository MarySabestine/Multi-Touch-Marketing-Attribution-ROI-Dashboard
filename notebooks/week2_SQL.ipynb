# %%
import sqlite3

conn = sqlite3.connect("marketing.db")

print("Connected successfully!")

conn.close()
# Out:
# Connected successfully!

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 7
#       5 import seaborn as sns
#       6 from datetime import datetime
# ----> 7 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
#conn = sqlite3.connect("marketing.db")
conn = psycopg2.connect("marketing.db")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #conn = sqlite3.connect("marketing.db")
# ----> 2 conn = psycopg2.connect("marketing.db")
#
# NameError: name 'psycopg2' is not defined

# %%
def load_dataset(file_path, parse_dates=None):
    return pd.read_csv(file_path, parse_dates=parse_dates)

# %%
Clean_Adspend = load_dataset(
    "../data/cleaned_data/cleaned_Adspend_Table.csv",
    parse_dates=["date"]
)

Clean_Weblogs = load_dataset(
    "../data/cleaned_data/cleaned_User_Weblogs.csv",
    parse_dates=["timestamp"]
)

Clean_Customer = load_dataset(
    "../data/cleaned_data/cleaned_Customer_Table.csv",
    parse_dates=[
        "first_touch_date",
        "last_touch_date",
        "conversion_date"
    ]
)

Clean_Conversion = load_dataset(
    "../data/cleaned_data/cleaned_Conversion_Table.csv",
    parse_dates=["conversion_date"]
)

# %%
Clean_Weblogs.to_sql(
    "user_weblogs",
    conn,
    if_exists="replace",
    index=False
)

Clean_Conversion.to_sql(
    "conversions",
    conn,
    if_exists="replace",
    index=False
)

Clean_Adspend.to_sql(
    "ad_spend",
    conn,
    if_exists="replace",
    index=False
)

Clean_Customer.to_sql(
    "Customer",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 10000

# %%
pd.read_sql("""
SELECT name
FROM sqlite_master
WHERE type='table';
""", conn)
# Out:
#            name
# 0  user_weblogs
# 1   conversions
# 2      ad_spend
# 3      Customer

# %%
query = """
SELECT *
FROM user_weblogs;
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#   user_id                  timestamp         region   device       channel  \
# 0  U00001  2025-05-14 18:56:35+00:00  North America  Desktop       Organic
# 1  U00001                       None  North America  Desktop    Tiktok Ads
# 2  U00002                       None  North America  Desktop    Tiktok Ads
# 3  U00002  2025-04-09 10:58:50+00:00  North America  Desktop  Facebook Ads
# 4  U00003  2025-01-23 07:05:32+00:00   Asia Pacific   Tablet       Organic
#
#           campaign    event_type      utm_source utm_medium     utm_campaign  \
# 0  Organic Landing         Visit  organic_search    organic  Organic Landing
# 1  Influencer Push  Product View      tiktok_ads     social  Influencer Push
# 2     UGC Campaign  Product View      tiktok_ads    organic     UGC Campaign
# 3      Retargeting         Visit    facebook_ads    organic      Retargeting
# 4  Organic Landing  Product View  organic_search    organic  Organic Landing
#
# ...

# %%
query = """
SELECT *
FROM ad_spend;
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#                         date       channel           campaign    spend  \
# 0  2025-01-01 00:00:00+00:00    Google Ads  Competitor Search  2185.43
# 1  2025-01-01 00:00:00+00:00  Facebook Ads        Winter Sale  4778.21
# 2  2025-01-01 00:00:00+00:00    Tiktok Ads    Influencer Push  3793.97
# 3  2025-01-01 00:00:00+00:00       Organic    Organic Landing     0.00
# 4  2025-01-02 00:00:00+00:00    Google Ads       Brand Search  3193.96
#
#    date_quarter date_month_name date_day_name  date_day_of_week  date_week  \
# 0             1         January     Wednesday                 2          1
# 1             1         January     Wednesday                 2          1
# 2             1         January     Wednesday                 2          1
# 3             1         January     Wednesday                 2          1
# 4             1         January      Thursday                 3          1
#
#    date_hour  date_is_weekend
# 0          0                0
# ...

# %%
query = """
SELECT *
FROM conversions;
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#   user_id            conversion_date  revenue  conversion_date_quarter  \
# 0  U00001  2025-05-15 09:56:35+00:00   427.99                        2
# 1  U00005  2025-02-24 19:28:00+00:00   470.38                        1
# 2  U00006  2025-04-26 04:32:00+00:00   853.58                        2
# 3  U00008  2025-06-23 04:00:04+00:00   790.46                        2
# 4  U00009  2025-06-13 17:55:21+00:00   385.54                        2
#
#   conversion_date_month_name conversion_date_day_name  \
# 0                        May                 Thursday
# 1                   February                   Monday
# 2                      April                 Saturday
# 3                       June                   Monday
# 4                       June                   Friday
#
#    conversion_date_day_of_week  conversion_date_week  conversion_date_hour  \
# 0                            3                    20                     9
# ...

# %%
query = """
SELECT *
FROM customer;
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#    customer_key user_id         region primary_device  \
# 0             1  U00001  North America        Desktop
# 1             2  U00002  North America        Desktop
# 2             3  U00003   Asia Pacific         Tablet
# 3             4  U00004   Asia Pacific         Mobile
# 4             5  U00005   Asia Pacific         Tablet
#
#             first_touch_date            last_touch_date  total_touchpoints  \
# 0  2025-05-14 18:56:35+00:00  2025-05-16 12:56:00+00:00                  2
# 1  2025-04-04 15:58:00+00:00  2025-04-09 10:58:50+00:00                  2
# 2  2025-01-23 07:05:32+00:00  2025-02-02 02:05:32+00:00                  4
# 3  2025-02-10 11:39:23+00:00  2025-02-12 19:39:00+00:00                  2
# 4  2025-02-21 15:28:06+00:00  2025-02-21 22:28:00+00:00                  2
#
#    conversion_flag            conversion_date  revenue  ...  \
# 0                1  2025-05-15 09:56:35+00:00   427.99  ...
# 1                0                       None     0.00  ...
# ...

# %% [markdown]
# Export Result for PowerBI

# %%
with open("../SQL/first_touch.sql", "r") as file:
    first_touch_query = file.read()
with open("../SQL/last_touch.sql", "r") as file:
    last_touch_query = file.read()
with open("../SQL/linear.sql", "r") as file:
    linear_query = file.read()

# %%
first_touch = pd.read_sql(first_touch_query, conn)
first_touch.to_csv("data/first_touch_results.csv", index=False)

last_touch = pd.read_sql(last_touch_query, conn)
last_touch.to_csv("data/last_touch_results.csv", index=False)

linear = pd.read_sql(linear_query, conn)
linear.to_csv("data/linear_results.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: customer_journey
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 first_touch = pd.read_sql(first_touch_query, conn)
#       2 first_touch.to_csv("data/first_touch_results.csv", index=False)
#       4 last_touch = pd.read_sql(last_touch_query, conn)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
# ...

# %%
customer_journey = """
CREATE VIEW customer_journey AS

SELECT
    cuw.user_id,
    cuw.timestamp,
    cuw.channel,
    cuw.campaign,
    ct.conversion_date,
    ct.revenue

FROM cleaned_User_Weblogs cuw
JOIN cleaned_Conversion_Table ct
ON cuw.user_id = ct.user_id
WHERE cuw.timestamp <= ct.conversion_date;
"""

# %%
first_touch_query = """
WITH ordered_journey AS (
    SELECT
        user_id,
        channel,
        revenue,
        ROW_NUMBER() OVER (
            PARTITION BY user_id
            ORDER BY timestamp
        ) AS touch_order
    FROM customer_journey
)

SELECT
    channel,
    SUM(revenue) AS first_touch_revenue
FROM ordered_journey
WHERE touch_order = 1
GROUP BY channel;
"""

# %%
first_touch_df = pd.read_sql(first_touch_query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: customer_journey
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 first_touch_df = pd.read_sql(first_touch_query, conn)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
# ...
