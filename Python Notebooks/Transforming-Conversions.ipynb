# %%
#Imports required libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Using Pandas library to read the csv file.This stores CSV file in ram.Dynamically stored.
conversions=pd.read_csv("/workspaces/Multi-Touch-Marketing-Attribution-ROI-Dashboard/Raw_Data/conversions.csv.xls")

# %%
#head() function is used to see first few rows of csv file.
conversions.head()
# Out:
#   user_id      conversion_date  revenue
# 0  U00001  2025-05-15 09:56:35   427.99
# 1  U00005  2025-02-24 19:28:00   470.38
# 2  U00006  2025-04-26 04:32:00   853.58
# 3  U00008  2025-06-23 04:00:04   790.46
# 4  U00009  2025-06-13 17:55:21   385.54

# %%
#Similar to head() , but retreives a random sample of rows for examining. 
conversions.sample(5)
# Out:
#      user_id      conversion_date  revenue
# 560   U03629  2025-05-08 15:09:25   383.08
# 1485  U09504  2025-06-02 19:24:27  1199.43
# 846   U05299  2025-04-15 01:32:00   615.36
# 1123  U07078  2025-07-07 07:19:45   978.75
# 768   U04816  2025-03-23 05:04:32   924.31

# %%
#Using info() function helps understand data
#Can verify Columns, total columns, Non-Null Columns, Datatypes
conversions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          1564 non-null   str
#  1   conversion_date  1564 non-null   str
#  2   revenue          1564 non-null   float64
# dtypes: float64(1), str(2)
# memory usage: 36.8 KB

# %%
#Describe() functions gives a statistical Summary of the dataframe.
conversions.describe()
# Out:
#            revenue
# count  1564.000000
# mean    641.044987
# std     329.734181
# min      75.770000
# 25%     363.585000
# 50%     637.220000
# 75%     929.212500
# max    1199.430000

# %%
#Converting Conversion_date column from str datatype to datetime dataype.
conversions['conversion_date'] = pd.to_datetime(conversions['conversion_date'])

#Normalizing datetime format.Converts time in datetime to zeros.
#Handles data efficiently while working with Power BI.
conversions['conversion_date'] = conversions['conversion_date'].dt.normalize()

# %%
#Using info() function helps understand data
#Can verify Columns, total columns, Non-Null Columns, Datatypes
#Using this particular line to check if the datatype is changed from str to datetime
conversions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          1564 non-null   str
#  1   conversion_date  1564 non-null   datetime64[us]
#  2   revenue          1564 non-null   float64
# dtypes: datetime64[us](1), float64(1), str(1)
# memory usage: 36.8 KB

# %%
#Checking Duplicates.
print("Duplicate rows:", conversions.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
#Checking missing values.
print(conversions.isnull().sum())
# Out:
# user_id            0
# conversion_date    0
# revenue            0
# dtype: int64

# %%
#Plotting boxplot using matplotlib for conversions 
plt.boxplot(conversions["revenue"])
plt.scatter(x = 1 + np.random.normal(0, 0.1, 1564),y=conversions["revenue"])
plt.ylabel("Revenue")
plt.xlabel("Box")
plt.show()

# %%
conversions.to_csv('/workspaces/Multi-Touch-Marketing-Attribution-ROI-Dashboard/Cleaned Data/Cleaned_Conversions.csv' , index=False)
